# %% [markdown]
# <img src="https://news.illinois.edu/files/6367/543635/116641.jpg" alt="University of Illinois" width="250"/>
#
# # STAT542: Statistical Learning_HW 1
#
# ## due 2023-02-12 ##
#
# * Yu-Ching Liao <ycliao3@illinois.edu>

# %% [markdown]
# # Basic Import

# %%
import numpy as np
import random as rd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from sklearn.linear_model import Lasso

# %% [markdown]
# # Problem 1

# %% [markdown]
# ![CleanShot%202023-02-09%20at%2023.53.10.png](attachment:CleanShot%202023-02-09%20at%2023.53.10.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## Get LHS and RHS

# %% [markdown]
# ![CleanShot%202023-01-31%20at%2000.10.42@2x.png](attachment:CleanShot%202023-01-31%20at%2000.10.42@2x.png)

# %% [markdown]
# ![CleanShot%202023-01-31%20at%2000.11.11@2x.png](attachment:CleanShot%202023-01-31%20at%2000.11.11@2x.png)

# %% [markdown]
# ## Get β̂

# %%
def LHS(ρ):
    return (6*ρ)/(1+ρ**2)

def RHS(r):
    return 2*r+r**(-1)

# %% [markdown]
# Now then we have the range for both ρ and r, we can then generate lists for both X and Y.

# %%
l1 = []
β̂ = []
l0 = []

ρ = rd.uniform(0,1)
r = rd.uniform(0.000000001,1)

while LHS(ρ)<RHS(r):
    ρ = rd.uniform(0,1)
    r = rd.uniform(0.000000001,1)

X = np.array([[1, ρ*r], 
            [ρ, r]])
Y = X @ np.array([[-1],
                [2]])
for λ in np.linspace(0.000001, 1, 1000):
    lasso = Lasso(alpha= λ, max_iter=1000000, fit_intercept=False)
    lasso.fit(X, Y)
    l1.append(np.linalg.norm(lasso.coef_, ord = 1))
    l0.append(np.linalg.norm(lasso.coef_, ord = 0))
    β̂.append(lasso.coef_)
    
figure, axis = plt.subplots(2)

axis[0].plot(l1, β̂, label = ["β̂1", "β̂2"])
axis[0].set_title("L1 Norm")
axis[0].legend()
    
# For Cosine Function
axis[1].plot(l1, l0, label = "L0 norm", color = "red")
axis[1].set_title("L0 Norm")
axis[1].legend()

figure.tight_layout()
plt.show()

# %% [markdown]
# It is not monotonic.

# %% [markdown]
# # Problem 3

# %% [markdown]
# ![CleanShot%202023-01-31%20at%2000.10.11@2x.png](attachment:CleanShot%202023-01-31%20at%2000.10.11@2x.png)

# %%
l1 = []
β̂ = []
l0 = []

ρ = rd.uniform(0,1)
r = rd.uniform(0.000000001,1)

while LHS(ρ)>RHS(r):
    ρ = rd.uniform(0,1)
    r = rd.uniform(0.000000001,1)

X = np.array([[1, ρ*r], 
            [ρ, r]])
Y = X @ np.array([[-1],
                [2]])
for λ in np.linspace(0.000001, 1, 1000):
    lasso = Lasso(alpha= λ, max_iter=1000000, fit_intercept=False)
    lasso.fit(X, Y)
    l1.append(np.linalg.norm(lasso.coef_, ord = 1))
    l0.append(np.linalg.norm(lasso.coef_, ord = 0))
    β̂.append(lasso.coef_)
    
figure, axis = plt.subplots(2)

axis[0].plot(l1, β̂, label = ["β̂1", "β̂2"])
axis[0].set_title("L1 Norm")
axis[0].legend()
    
# For Cosine Function
axis[1].plot(l1, l0, label = "L0 norm", color = 'red')
axis[1].set_title("L0 Norm")
axis[1].legend()

figure.tight_layout()
plt.show()

# %% [markdown]
# It is monotonic.

# %% [markdown]
# <img src="https://news.illinois.edu/files/6367/543635/116641.jpg" alt="University of Illinois" width="250"/>
